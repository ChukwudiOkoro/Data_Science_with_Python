# %%
import pandas as pd

# %%
#list is for girls i had dips on but ...
Girls = [" Ada", "Amara ", "oluchi", "Amara", "kareen", "chidinso" ]
ages = [22, 10, 12, 12, 25, 12]

# %%
#store list in a dictionary
dict_Girls = { "Girls": Girls, "Age": ages}

# %%
# create the data frame 
df_Girls = pd.DataFrame. from_dict(dict_Girls)

# %%
df_Girls
# Out:
#       Girls  Age
# 0       Ada   22
# 1    Amara    10
# 2    oluchi   12
# 3     Amara   12
# 4    kareen   25
# 5  chidinso   12

# %% [markdown]
# # 1.Title Hello world
#
# ## 1.1 Subtitle

# %%
"Hello World"
type("Hello World")
# Out:
# str

# %%
# print my name
print ("Okoro")
# Out:
# Okoro

# %% [markdown]
# # 2  Data Type

# %%
4-1, type(4-1)
# Out:
# (3, int)

# %%
1+2
# Out:
# 3

# %%
4-1
# Out:
# 3

# %%
type(True)
# Out:
# bool

# %%
type("Hello World")
# Out:
# str

# %%
print ("hello World".upper())
print ( "hello world".lower())
print ("Kallisto money now". title())
# Out:
# HELLO WORLD
# hello world
# Kallisto Money Now

# %%
"hello World".count ('o')
# Out:
# 2

# %%
"hello World".replace('o','u')
# Out:
# 'hellu Wurld'

# %% [markdown]
# # 3   Variables

# %%
message_1  = "I'm learning python"

message_1
# Out:
# "I'm learning python"

# %%
message_2 = "and I am enjoying it."
message_2
# Out:
# 'and I am enjoying it.'

# %%
message_1 + message_2
# Out:
# "I'm learning pythonand I am enjoying it."

# %%
message_1 + ' '+ message_2
# Out:
# "I'm learning python and I am enjoying it."

# %%
f" {message_1}  abc {message_2} "
# Out:
# " I'm learning python  abc and I am enjoying it. "

# %% [markdown]
# # 4 List

# %%
countries  = [ 'United States', 'India', 'China', 'Brazil', 'Biafra', 'Nigeria']

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Biafra', 'Nigeria']

# %%
#indexing
print(countries[0])
print(countries[1])
print(countries[2])
print(countries[-2])
print(countries[-1])
print(countries[3]) 
print(countries[-3])
# Out:
# United States
# India
# China
# Biafra
# Nigeria
# Brazil
# Brazil

# %%
countries[-1]
# Out:
# 'Nigeria'

# %%
countries[-4]
# Out:
# 'China'

# %%
# slicing
#list_name[start : stop]

# %%
countries[0:3]
# Out:
# ['United States', 'India', 'China']

# %%
countries[:1]
# Out:
# ['United States']

# %%
countries[1:]
# Out:
# ['India', 'China', 'Brazil', 'Biafra', 'Nigeria']

# %%
countries[:2]
# Out:
# ['United States', 'India']

# %% [markdown]
# ### 4.0.1  Adding Elements to a list

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Biafra', 'Nigeria']

# %%
countries.append('Canada')

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Biafra', 'Nigeria', 'Canada']

# %%
countries.insert(0,'Ghana')

# %%
countries
# Out:
# ['Ghana',
#  'United States',
#  'India',
#  'China',
#  'Brazil',
#  'Biafra',
#  'Nigeria',
#  'Canada']

# %%
countries_2 = ['UK', 'Germany', 'Austria']

# %%
countries_2
# Out:
# ['UK', 'Germany', 'Austria']

# %%
countries + countries_2
# Out:
# ['Ghana',
#  'United States',
#  'India',
#  'China',
#  'Brazil',
#  'Biafra',
#  'Nigeria',
#  'Canada',
#  'UK',
#  'Germany',
#  'Austria']

# %%
nested_list = [countries, countries_2]

# %%
nested_list
# Out:
# [['Ghana',
#   'United States',
#   'India',
#   'China',
#   'Brazil',
#   'Biafra',
#   'Nigeria',
#   'Canada'],
#  ['UK', 'Germany', 'Austria']]

# %% [markdown]
# ### 4.0.2 Removing an element

# %%
countries.remove('United States')

# %%
countries
# Out:
# ['Ghana', 'India', 'China', 'Brazil', 'Biafra', 'Nigeria', 'Canada']

# %%
countries.pop(-1)
# Out:
# 'Canada'

# %%
countries
# Out:
# ['Ghana', 'India', 'China', 'Brazil', 'Biafra', 'Nigeria']

# %%
del countries[0]

# %%
countries
# Out:
# ['India', 'China', 'Brazil', 'Biafra', 'Nigeria']

# %% [markdown]
# ### 4.0.3 Sorting a list

# %%
numbers = [4,3, 10, 7, 9,1, 14, 11, 12,0]

# %%
numbers.sort()

# %%
numbers
# Out:
# [0, 1, 3, 4, 7, 9, 10, 11, 12, 14]

# %%
numbers.sort(reverse=True)

# %%
numbers
# Out:
# [14, 12, 11, 10, 9, 7, 4, 3, 1, 0]

# %% [markdown]
# ### 4.0.4  Update an Element

# %%
numbers[0] = 1000
numbers
# Out:
# [1000, 12, 11, 10, 9, 7, 4, 3, 1, 0]

# %% [markdown]
# ### 4.0.5 Copying a list

# %%
countries_2
# Out:
# ['UK', 'Germany', 'Austria']

# %%
next_list = countries_2[:]

# %%
next_list
# Out:
# ['UK', 'Germany', 'Austria']

# %%
next_list_2 =countries.copy()

# %%
next_list_2
# Out:
# ['India', 'China', 'Brazil', 'Biafra', 'Nigeria']

# %% [markdown]
#   # 5  Dictionary

# %%
my_dict = {'key1' : 'value1' , 'key2' :  'values2'}

# %%
my_data  =  { 'name' : 'Gad' ,'age' :223 , 'status'  :  'grandelder'}

# %%
my_data
# Out:
# {'name': 'Gad', 'age': 223, 'status': 'grandelder'}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age', 'status'])

# %%
my_data.values()
# Out:
# dict_values(['Gad', 223, 'grandelder'])

# %%
my_data['height']= 1.9

# %%
my_data.update({'height': 1.92})  # value was change later from 1.92

# %%
my_data.items()
# Out:
# dict_items([('name', 'Gad'), ('age', 223), ('status', 'grandelder'), ('height', 1.92)])

# %% [markdown]
# ###  5.0.1 Copy a dictionary

# %%
new_dict = my_data.copy() # this method of copying will not effect change in value if updated in the my_data afterwards

# %%
new_dict
# Out:
# {'name': 'Gad', 'age': 223, 'status': 'grandelder', 'height': 1.92}

# %%
new_dict2  = my_data  # this  method will effect change in value if updated in the my_data afterwards

# %%
new_dict2
# Out:
# {'height': 10.92}

# %%
my_data.update({'height': 10.92})   #e.g is below with update effected in the value

# %%
new_dict2
# Out:
# {'name': 'Gad', 'age': 223, 'status': 'grandelder', 'height': 10.92}

# %% [markdown]
# ###  5.0.2   Remove Element

# %%
my_data.pop('name')
# Out:
# 'Gad'

# %%
my_data
# Out:
# {'age': 223, 'status': 'grandelder', 'height': 10.92}

# %%
del my_data ['age']

# %%
my_data
# Out:
# {'status': 'grandelder', 'height': 10.92}

# %%
my_data.clear()  # clears all the values and leaves empty dictionary

# %%
my_data
# Out:
# {}

# %% [markdown]
# #  IF Statement

# %%
age = 40

if age>= 18 and age < 50:
    print ("you are an Adult !")

elif age >=50 :
     print ("you are old")
else:
    print("you are a punk kid")
# Out:
# you are an Adult !

# %% [markdown]
# #  7  For  Loop

# %%
countries
# Out:
# ['India', 'China', 'Brazil', 'Biafra', 'Nigeria']

# %%
for i , country in enumerate (countries):
    print (i)
    print(country)

# %%
my_file = {'name' : 'Frank', 'age' :27}
my_file
# Out:
# {'name': 'Frank', 'age': 27}

# %%
for key, value in my_file.items():
    print(key)
    print(value)
# Out:
# name
# Frank
# age
# 27

# %% [markdown]
# # 8 Function

# %%
# def  function (parameteeters): #this is how to build a function
#     <code>
#     return<data>

# %%
def sum_values(a,b):
    x = a+b
    return x

# %%
sum_values(1,3)
# Out:
# 4

# %%
sum_values(-1,0)
# Out:
# -1

# %% [markdown]
# ### 8.1 Built- in Functions

# %%
countries
# Out:
# ['India', 'China', 'Brazil', 'Biafra', 'Nigeria']

# %%
len(countries)
# Out:
# 5

# %%
max([10,75,848,85,93,0,78])    #maximum value funct
# Out:
# 848

# %%
min([10,75,848,85,93,0,78])
# Out:
# 0

# %%
type(countries)  #type funct
# Out:
# list

# %%
for i  in   range (1,10,2):
    print(i)                    # range is used to define limits and the last number is the increment value e.g by 2
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# # 9 module

# %% [markdown]
# ### 9.1 Os Module

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\steph'

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.android',
#  '.cisco',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.dotnet',
#  '.Icecream Image Resizer',
#  '.Icecream PDF Converter',
#  '.Icecream PDF Split and Merge',
#  '.Icecream Screen Recorder',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.librarymanager',
#  '.matplotlib',
#  '.ms-ad',
#  '.nvidia-omniverse',
#  '.openjfx',
#  '.sambox.cache',
#  '.spyder-py3',
#  '.ssh',
#  '.templateengine',
#  '.vscode',
#  '3D Objects',
#  'anaconda3',
#  'anaconda_projects',
#  'ansel',
#  'Anwendungsdaten',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Documents',
#  'Downloads',
#  'Druckumgebung',
#  'Eigene Dateien',
#  'Favorites',
#  'IntelGraphicsProfiles',
#  'learn python for datascience.ipynb',
#  'Links',
#  'Local Settings',
#  'Lokale Einstellungen',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'Netzwerkumgebung',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
# ...
